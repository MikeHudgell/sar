# %%
data = pd.read_csv('/home/ubuntu/data/ihs/ihs_feb16.csv')
# Out:
# /usr/local/lib/python3.4/dist-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (58,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# df = data[['imo','grosstonnage','mmsi','IHSShipName','IHSShipStatus','IHSShiptypeLevel5','IHSFlagName','IHSDraught','IHSLengthOverallLOA','UKHOYearOfBuild']]

df = data[['grosstonnage','IHSFlagName']]

# %%
df.head()
# Out:
#    grosstonnage     IHSFlagName
# 0           551          Panama
# 1          2000  Cayman Islands
# 2           178  United Kingdom
# 3           264          Greece
# 4           234    Saudi Arabia

# %%
import seaborn as sns
sns.set()

bins = [0, 250, 500, 1000, 2000]
group_names = ['Small', 'Med', 'Med-Large', 'Large']

df['sizes'] = pd.cut(df['grosstonnage'], bins, labels=group_names)

df.head()
# Out:
# /usr/local/lib/python3.4/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    grosstonnage     IHSFlagName      sizes
# 0           551          Panama  Med-Large
# 1          2000  Cayman Islands      Large
# 2           178  United Kingdom      Small
# 3           264          Greece        Med
# 4           234    Saudi Arabia      Small

# %%
df[['grosstonnage','sizes', 'IHSFlagName']].groupby(['IHSFlagName','sizes']).agg([ 'count'])
# Out:
#                                    grosstonnage
#                                           count
# IHSFlagName              sizes
# Albania                  Small               36
#                          Med                 13
#                          Med-Large            3
#                          Large               10
# Algeria                  Small               53
#                          Med                 46
#                          Med-Large            7
#                          Large                4
# Angola                   Small               59
#                          Med                101
#                          Med-Large           24
#                          Large                7
# Anguilla                 Small                2
# Antigua & Barbuda        Small                4
#                          Med                  6
#                          Med-Large            7
#                          Large               71
# Argentina                Small              156
#                          Med                164
#                          Med-Large           87
#                          Large               56
# Australia                Small              433
#                          Med                251
#                          Med-Large           78
#                          Large               51
# Austria                  Med                  1
# Azerbaijan               Small               54
#                          Med                 27
#                          Med-Large           23
#                          Large               38
# ...                                         ...
# United States Of America Med               1273
#                          Med-Large          604
#                          Large              393
# Unknown                  Small             3755
#                          Med               1975
#                          Med-Large         1046
#                          Large              457
# Uruguay                  Small               35
#                          Med                 39
#                          Med-Large           32
#                          Large                9
# Vanuatu                  Small               22
#                          Med                 92
#                          Med-Large           51
#                          Large               97
# Venezuela                Small              191
#                          Med                143
#                          Med-Large           59
#                          Large               38
# Vietnam                  Small              288
#                          Med                425
#                          Med-Large          246
#                          Large              416
# Virgin Islands, British  Small               24
#                          Med                 22
#                          Med-Large            5
# Yemen                    Small               19
#                          Med                 16
#                          Med-Large            9
#                          Large                1
#
# [685 rows x 1 columns]

# %%
df1 = df[['sizes', 'IHSFlagName']]
sns.pairplot(df, hue="grosstonnage")
# Out:
# --------------------------------------------------------------------------
# KeyboardInterrupt                        Traceback (most recent call last)
# <ipython-input-32-ab8f5e96153e> in <module>()
#       1 df1 = df[['sizes', 'IHSFlagName']]
# ----> 2 sns.pairplot(df, hue="grosstonnage")
#
# /usr/local/lib/python3.4/dist-packages/seaborn/linearmodels.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    1607     if grid.square_grid:
#    1608         if diag_kind == "hist":
# -> 1609             grid.map_diag(plt.hist, **diag_kws)
#    1610         elif diag_kind == "kde":
#    1611             diag_kws["legend"] = False
#
# /usr/local/lib/python3.4/dist-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1346                 else:
#    1347                     func(vals, color=self.palette, histtype="barstacked",
# -> 1348                          **kwargs)
#    1349             else:
#    1350                 for k, label_k in enumerate(self.hue_names):
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, data, **kwargs)
#    3080                       histtype=histtype, align=align, orientation=orientation,
#    3081                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3082                       stacked=stacked, data=data, **kwargs)
#    3083     finally:
#    3084         ax._hold = washold
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6274                 patch = _barfunc(bins[:-1]+boffset, height, width,
#    6275                                  align='center', log=log,
# -> 6276                                  color=c, **{bottom_kwarg: bottom})
#    6277                 patches.append(patch)
#    6278                 if stacked:
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/axes/_axes.py in bar(self, left, height, width, bottom, **kwargs)
#    2175             ymin = max(ymin * 0.9, 1e-100)
#    2176             self.dataLim.intervaly = (ymin, ymax)
# -> 2177         self.autoscale_view()
#    2178
#    2179         bar_container = BarContainer(patches, errorbar, label=label)
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/axes/_base.py in autoscale_view(self, tight, scalex, scaley)
#    2260             stickies = [artist.sticky_edges for artist in self.get_children()]
#    2261             x_stickies = sum([sticky.x for sticky in stickies], [])
# -> 2262             y_stickies = sum([sticky.y for sticky in stickies], [])
#    2263             if self.get_xscale().lower() == 'log':
#    2264                 x_stickies = [xs for xs in x_stickies if xs > 0]
#
# KeyboardInterrupt:
